# %%
## import libraries
import numpy as np
import pandas as pd
from pathlib import Path
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline


project_root = Path.cwd().parent

data_folder = project_root / 'data'/'processed'

# Define the path to the CSV file
file_path = data_folder / 'class_data.csv'

# Read the data using pandas
df = pd.read_csv(file_path)

# Display the data
df.head(10)
# Out:
#    user_id  label  Account type  Duration of Credit (month)  \
# 0   586266      1             1                          18
# 1   392565      1             1                           9
# 2   204665      1             2                          12
# 3   393307      1             1                          12
# 4   627375      1             1                          12
# 5   705933      1             1                          10
# 6   231128      1             1                           8
# 7   103992      1             1                           6
# 8    67751      1             4                          18
# 9   493932      1             2                          24
#
#    Payment Status of Previous Credit  Purpose  Credit Amount  Savings type  \
# 0                                  4        2           1049             1
# 1                                  4        0           2799             1
# 2                                  2        9            841             2
# ...

# %%
df.describe()
# Out:
#              user_id        label  Account type  Duration of Credit (month)  \
# count    1000.000000  1000.000000   1000.000000                 1000.000000
# mean   396518.897000     0.700000      2.577000                   20.903000
# std    225382.045777     0.458487      1.257638                   12.058814
# min       505.000000     0.000000      1.000000                    4.000000
# 25%    201780.000000     0.000000      1.000000                   12.000000
# 50%    395127.500000     1.000000      2.000000                   18.000000
# 75%    586323.000000     1.000000      4.000000                   24.000000
# max    797738.000000     1.000000      4.000000                   72.000000
#
#        Payment Status of Previous Credit      Purpose  Credit Amount  \
# count                         1000.00000  1000.000000     1000.00000
# mean                             2.54500     2.828000     3271.24800
# std                              1.08312     2.744439     2822.75176
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 22 columns):
#  #   Column                             Non-Null Count  Dtype
# ---  ------                             --------------  -----
#  0   user_id                            1000 non-null   int64
#  1   label                              1000 non-null   int64
#  2   Account type                       1000 non-null   int64
#  3   Duration of Credit (month)         1000 non-null   int64
#  4   Payment Status of Previous Credit  1000 non-null   int64
#  5   Purpose                            1000 non-null   int64
#  6   Credit Amount                      1000 non-null   int64
#  7   Savings type                       1000 non-null   int64
#  8   Length of current employment       1000 non-null   int64
#  9   Instalment per cent                1000 non-null   float64
#  10  Marital Status                     1000 non-null   int64
# ...

# %%
fields = ['label', 'Account type', 'Payment Status of Previous Credit',
         'Purpose', 'Savings type', 'Marital Status', 'Most valuable available asset',
         'Type of apartment', 'Occupation', 'Telephone', 'Foreign Worker']

df[fields] = df[fields].astype(str)
df['Instalment per cent'] = df['Instalment per cent']/100

df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 22 columns):
#  #   Column                             Non-Null Count  Dtype
# ---  ------                             --------------  -----
#  0   user_id                            1000 non-null   int64
#  1   label                              1000 non-null   object
#  2   Account type                       1000 non-null   object
#  3   Duration of Credit (month)         1000 non-null   int64
#  4   Payment Status of Previous Credit  1000 non-null   object
#  5   Purpose                            1000 non-null   object
#  6   Credit Amount                      1000 non-null   int64
#  7   Savings type                       1000 non-null   object
#  8   Length of current employment       1000 non-null   int64
#  9   Instalment per cent                1000 non-null   float64
#  10  Marital Status                     1000 non-null   object
# ...

# %%
df.describe()
# Out:
#              user_id  Duration of Credit (month)  Credit Amount  \
# count    1000.000000                 1000.000000     1000.00000
# mean   396518.897000                   20.903000     3271.24800
# std    225382.045777                   12.058814     2822.75176
# min       505.000000                    4.000000      250.00000
# 25%    201780.000000                   12.000000     1365.50000
# 50%    395127.500000                   18.000000     2319.50000
# 75%    586323.000000                   24.000000     3972.25000
# max    797738.000000                   72.000000    18424.00000
#
#        Length of current employment  Instalment per cent   Guarantors  \
# count                   1000.000000          1000.000000  1000.000000
# mean                       3.384000             0.000297     1.145000
# std                        1.208306             0.000112     0.477706
# min                        1.000000             0.000100     1.000000
# ...

# %%
df['Age'].describe()
# Out:
# count    1000.00000
# mean       35.54200
# std        11.35267
# min        19.00000
# 25%        27.00000
# 50%        33.00000
# 75%        42.00000
# max        75.00000
# Name: Age, dtype: float64

# %%
df.columns
# Out:
# Index(['user_id', 'label', 'Account type', 'Duration of Credit (month)',
#        'Payment Status of Previous Credit', 'Purpose', 'Credit Amount',
#        'Savings type', 'Length of current employment', 'Instalment per cent',
#        'Marital Status', 'Guarantors', 'Duration in Current address',
#        'Most valuable available asset', 'Age', 'Concurrent Credits',
#        'Type of apartment', 'No of Credits at this Bank', 'Occupation',
#        'No of dependents', 'Telephone', 'Foreign Worker'],
#       dtype='object')

# %%
obj_df = df[fields]

# Use list comprehension to get the value counts for each column
value_counts = [obj_df[col].value_counts() for col in obj_df.columns]

# Print the value counts for each column
[value_count for value_count in value_counts]
# Out:
# [label
#  1    700
#  0    300
#  Name: count, dtype: int64,
#  Account type
#  4    394
#  1    274
#  2    269
#  3     63
#  Name: count, dtype: int64,
#  Payment Status of Previous Credit
#  2    530
#  4    293
#  3     88
#  1     49
#  0     40
#  Name: count, dtype: int64,
#  Purpose
#  3     280
#  0     234
#  2     181
#  1     103
#  9      97
#  6      50
#  5      22
#  10     12
#  4      12
#  8       9
#  Name: count, dtype: int64,
#  Savings type
#  1    603
#  5    183
#  2    103
#  3     63
#  4     48
#  Name: count, dtype: int64,
#  Marital Status
#  3    548
#  2    310
#  4     92
#  1     50
#  Name: count, dtype: int64,
#  Most valuable available asset
#  3    332
#  1    282
#  2    232
#  4    154
#  Name: count, dtype: int64,
#  Type of apartment
#  2    714
#  1    179
#  3    107
#  Name: count, dtype: int64,
#  Occupation
#  3    630
#  2    200
#  4    148
#  1     22
#  Name: count, dtype: int64,
#  Telephone
#  1    596
#  2    404
# ...
