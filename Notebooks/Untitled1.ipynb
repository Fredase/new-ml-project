# %%
project_root = Path.cwd().parent

project_root
# Out:
# WindowsPath('C:/Users/USER/Desktop/QC')

# %%
# Define the path to the data sub-folder
data_folder = project_root / 'data'/'raw'

# Define the path to the CSV file
file_path = data_folder / 'classification_data.csv'

# Read the data using pandas
df = pd.read_csv(file_path)

# Display the data
df.head(10)
# Out:
#    user_id  label  Account type  Duration of Credit (month)  \
# 0   586266      1             1                          18
# 1   392565      1             1                           9
# 2   204665      1             2                          12
# 3   393307      1             1                          12
# 4   627375      1             1                          12
# 5   705933      1             1                          10
# 6   231128      1             1                           8
# 7   103992      1             1                           6
# 8    67751      1             4                          18
# 9   493932      1             2                          24
#
#    Payment Status of Previous Credit  Purpose  Credit Amount  Savings type  \
# 0                                  4        2           1049             1
# 1                                  4        0           2799             1
# 2                                  2        9            841             2
# ...

# %%
df.shape
# Out:
# (1000, 22)

# %%
df.tail(10)
# Out:
#      user_id  label  Account type  Duration of Credit (month)  \
# 990   638624      0             1                          18
# 991    18037      0             2                          24
# 992   500888      0             1                          18
# 993   157554      0             1                          18
# 994   488958      0             1                          12
# 995   355104      0             1                          24
# 996   407505      0             1                          24
# 997   115061      0             4                          21
# 998   283292      0             2                          12
# 999   232249      0             1                          30
#
#      Payment Status of Previous Credit  Purpose  Credit Amount  Savings type  \
# 990                                  2        6            750             1
# 991                                  2        1          12579             1
# ...

# %%
df.sample(5)
# Out:
#      user_id  label  Account type  Duration of Credit (month)  \
# 911   201360      0             1                          12
# 464   454589      1             2                          12
# 492   372092      1             1                          18
# 899   375328      0             4                          10
# 807     2787      0             1                          60
#
#      Payment Status of Previous Credit  Purpose  Credit Amount  Savings type  \
# 911                                  4        0            691             1
# 464                                  2        0           7472             5
# 492                                  0        9           3104             1
# 899                                  2        0           1309             5
# 807                                  3        9           6836             1
#
#      Length of current employment  Instalment per cent  ...  \
# 911                             5                    4  ...
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 22 columns):
#  #   Column                             Non-Null Count  Dtype
# ---  ------                             --------------  -----
#  0   user_id                            1000 non-null   int64
#  1   label                              1000 non-null   int64
#  2   Account type                       1000 non-null   int64
#  3   Duration of Credit (month)         1000 non-null   int64
#  4   Payment Status of Previous Credit  1000 non-null   int64
#  5   Purpose                            1000 non-null   int64
#  6   Credit Amount                      1000 non-null   int64
#  7   Savings type                       1000 non-null   int64
#  8   Length of current employment       1000 non-null   int64
#  9   Instalment per cent                1000 non-null   int64
#  10  Marital Status                     1000 non-null   int64
# ...

# %%
df.columns
# Out:
# Index(['user_id', 'label', 'Account type', 'Duration of Credit (month)',
#        'Payment Status of Previous Credit', 'Purpose', 'Credit Amount',
#        'Savings type', 'Length of current employment', 'Instalment per cent',
#        'Marital Status', 'Guarantors', 'Duration in Current address',
#        'Most valuable available asset', 'Age', 'Concurrent Credits',
#        'Type of apartment', 'No of Credits at this Bank', 'Occupation',
#        'No of dependents', 'Telephone', 'Foreign Worker'],
#       dtype='object')

# %%
# Define the path to the second CSV file
file_path1 = data_folder /'users_data.csv'

# Read the data using pandas
df_1 = pd.read_csv(file_path1)

# Display the data
df_1.head(10)
# Out:
#    user_id  loan_score  device_rating  data_quality  ltv_rate  bureau_score  \
# 0   146245         7.4           0.70          0.00       1.9         0.076
# 1   248802         7.8           0.88          0.00       2.6         0.098
# 2    13873         7.8           0.76          0.04       2.3         0.092
# 3    35230        11.2           0.28          0.56       1.9         0.075
# 4   653322         7.4           0.70          0.00       1.9         0.076
# 5    61550         7.4           0.66          0.00       1.8         0.075
# 6   399240         7.9           0.60          0.06       1.6         0.069
# 7   385139         7.3           0.65          0.00       1.2         0.065
# 8   572500         7.8           0.58          0.02       2.0         0.073
# 9    59826         7.5           0.50          0.36       6.1         0.071
#
#    total_tenure  months_active  savings_score  tx_score  usage_score  \
# ...

# %%
df_1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1599 entries, 0 to 1598
# Data columns (total 13 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   user_id        1599 non-null   int64
#  1   loan_score     1599 non-null   float64
#  2   device_rating  1599 non-null   float64
#  3   data_quality   1599 non-null   float64
#  4   ltv_rate       1599 non-null   float64
#  5   bureau_score   1599 non-null   float64
#  6   total_tenure   1599 non-null   float64
#  7   months_active  1599 non-null   float64
#  8   savings_score  1599 non-null   float64
#  9   tx_score       1599 non-null   float64
#  10  usage_score    1599 non-null   float64
#  11  airtime_score  1599 non-null   float64
#  12  cluster        0 non-null      float64
# dtypes: float64(12), int64(1)
# memory usage: 162.5 KB

# %%
df_1.columns
# Out:
# Index(['user_id', 'loan_score', 'device_rating', 'data_quality', 'ltv_rate',
#        'bureau_score', 'total_tenure', 'months_active', 'savings_score',
#        'tx_score', 'usage_score', 'airtime_score', 'cluster'],
#       dtype='object')

# %%
df_1.shape
# Out:
# (1599, 13)

# %%
new_df = pd.merge(df, df_1, on='user_id', how='outer')

new_df.shape
# Out:
# (2598, 34)

# %%
new_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2598 entries, 0 to 2597
# Data columns (total 34 columns):
#  #   Column                             Non-Null Count  Dtype
# ---  ------                             --------------  -----
#  0   user_id                            2598 non-null   int64
#  1   label                              1000 non-null   float64
#  2   Account type                       1000 non-null   float64
#  3   Duration of Credit (month)         1000 non-null   float64
#  4   Payment Status of Previous Credit  1000 non-null   float64
#  5   Purpose                            1000 non-null   float64
#  6   Credit Amount                      1000 non-null   float64
#  7   Savings type                       1000 non-null   float64
#  8   Length of current employment       1000 non-null   float64
#  9   Instalment per cent                1000 non-null   float64
#  10  Marital Status                     1000 non-null   float64
# ...
